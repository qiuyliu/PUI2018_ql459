# %% [markdown]
# # Imports (compatible for Python 2 and Python 3)

# %%
try:
    import urllib2 as ulib
except ImportError:
    import urllib3 as ulib

try:
    from StringIO import BytesIO as io
except ImportError:
    from io import BytesIO as io

try:
    from urllib import urlencode as urlencode
except ImportError:
    from urllib.parse import urlencode as urlencode
    
try:
    from urllib import urlopen as urlopen
except ImportError:
    from urllib.request import urlopen as urlopen
    
try:
    from urllib2 import HTTPError as HTTPError
except ImportError:
    from urllib.error import HTTPError as HTTPError

import ast
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-6-c72e23cf90c4> in <module>()
#       1 try:
# ----> 2     import urllib2 as ulib
#       3 except ImportError:
#
# ImportError: No module named 'urllib2'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# <ipython-input-6-c72e23cf90c4> in <module>()
#       2     import urllib2 as ulib
#       3 except ImportError:
# ----> 4     import urllib3 as ulib
#       5
#       6 try:
#
# ImportError: No module named 'urllib3'

# %%
API_URL = 'https://fb55.carto.com:443/api/v2/sql?q='

def queryCartoDB(query, formatting = 'CSV', source = API_URL):
    '''queries carto datasets from a given carto account
    Arguments: 
    query - string: a valid sql query string
    format - outlut format  OPTIONAL (default CSV)
    source - a valid sql api endpoint OPTIONAL (default carto fb55 account)
    Returns:
    the return of the sql query AS A STRING
    NOTES:
    designed for the carto API, tested only with CSV return format'''
    
    
    data = urlencode({'format': formatting, 'q': query}).encode("utf-8")
    try:
        response = urlopen(source, data)
        return response.read()
    except HTTPError as e:
        raise (ValueError('\n'.join(ast.literal_eval(e.readline())['error'])))
        
def get_data(query):
    try:
        return pd.read_csv(io(queryCartoDB(query)), sep = ',')
    except ValueError as v:
        print (str(v))

# %%
query = '''SELECT * FROM fb55.citibike; '''
table = get_data(query)
table.head(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-e47b9ae1c7cc> in <module>()
#       1 query = '''SELECT * FROM fb55.citibike; '''
# ----> 2 table = get_data(query)
#       3 table.head(5)
#
# <ipython-input-3-dbda7bfb2c3e> in get_data(query)
#      22 def get_data(query):
#      23     try:
# ---> 24         return pd.read_csv(io(queryCartoDB(query)), sep = ',')
#      25     except ValueError as v:
#      26         print (str(v))
#
# NameError: name 'pd' is not defined

# %%
#Sort data by start_station_id, tripduration 
query = '''
SELECT * FROM fb55.citibike
ORDER BY start_station_id ASC, tripduration DESC
'''

table = get_data(query)
table.head(10)
# Out:
#    the_geom start_station_name  the_geom_webmercator  field_1  \
# 0       NaN   W 52 St & 11 Ave                   NaN     9115
# 1       NaN   W 52 St & 11 Ave                   NaN     2051
# 2       NaN   W 52 St & 11 Ave                   NaN    40355
# 3       NaN   W 52 St & 11 Ave                   NaN    12996
# 4       NaN   W 52 St & 11 Ave                   NaN    11359
# 5       NaN   W 52 St & 11 Ave                   NaN    13695
# 6       NaN   W 52 St & 11 Ave                   NaN     9802
# 7       NaN   W 52 St & 11 Ave                   NaN    11301
# 8       NaN   W 52 St & 11 Ave                   NaN    20364
# 9       NaN   W 52 St & 11 Ave                   NaN    24990
#
#    start_station_longitude  tripduration               starttime  \
# 0               -73.993929          2099  2015-02-03 10:28:00+00
# 1               -73.993929          1944  2015-02-01 12:39:00+00
# 2               -73.993929          1914  2015-02-07 09:49:00+00
# ...

# %%
#Only checking trips with duration <= 3 hours 
query = '''
SELECT * FROM fb55.citibike
WHERE tripduration <= 3 * 3600
ORDER BY start_station_id ASC, tripduration DESC
'''

table = get_data(query)
table.head(5)
# Out:
#    the_geom start_station_name  the_geom_webmercator  field_1  \
# 0       NaN   W 52 St & 11 Ave                   NaN     9115
# 1       NaN   W 52 St & 11 Ave                   NaN     2051
# 2       NaN   W 52 St & 11 Ave                   NaN    40355
# 3       NaN   W 52 St & 11 Ave                   NaN    12996
# 4       NaN   W 52 St & 11 Ave                   NaN    11359
#
#    start_station_longitude  tripduration               starttime  \
# 0               -73.993929          2099  2015-02-03 10:28:00+00
# 1               -73.993929          1944  2015-02-01 12:39:00+00
# 2               -73.993929          1914  2015-02-07 09:49:00+00
# 3               -73.993929          1801  2015-02-04 06:32:00+00
# 4               -73.993929          1678  2015-02-03 18:21:00+00
#
#                  stoptime  start_station_id  cartodb_id  \
# 0  2015-02-03 11:02:00+00                72        9054
# 1  2015-02-01 13:12:00+00                72        1983
# ...

# %%
#Only show the top/last 10 records 
query = '''
SELECT * FROM fb55.citibike
ORDER BY cartodb_id DESC
LIMIT 10;
'''

table = get_data(query)
table.head(10)
# Out:
#    the_geom     start_station_name  the_geom_webmercator  field_1  \
# 0       NaN         E 4 St & 2 Ave                   NaN    46199
# 1       NaN     Carmine St & 6 Ave                   NaN    46198
# 2       NaN        5 Ave & E 29 St                   NaN    46197
# 3       NaN        5 Ave & E 29 St                   NaN    46196
# 4       NaN        W 20 St & 8 Ave                   NaN    46195
# 5       NaN        1 Ave & E 44 St                   NaN    46194
# 6       NaN        E 20 St & 2 Ave                   NaN    46193
# 7       NaN  Warren St & Church St                   NaN    46192
# 8       NaN       W 47 St & 10 Ave                   NaN    46191
# 9       NaN        W 17 St & 8 Ave                   NaN    46190
#
#    start_station_longitude  tripduration               starttime  \
# 0               -73.989780           917  2015-02-07 23:59:00+00
# 1               -74.002150           548  2015-02-07 23:58:00+00
# ...

# %%
#List all unique start_station_id values 
query = '''
SELECT DISTINCT start_station_id FROM fb55.citibike
;
'''

table = get_data(query)
table.head(5)
# Out:
#    start_station_id  Unnamed: 1
# 0               120         NaN
# 1               285         NaN
# 2               251         NaN
# 3               195         NaN
# 4               453         NaN

# %%
#Count the number of trips
query = '''
SELECT COUNT(*) FROM fb55.citibike
;
'''

table = get_data(query)
table.head(5)
# Out:
#    count  Unnamed: 1
# 0  46200         NaN

# %%
#Find the average/min/max trip duration
query = '''
SELECT AVG(tripduration), MIN(tripduration), MAX(tripduration) FROM fb55.citibike
;
'''
table = get_data(query)
table.head(5)
# Out:
#           avg  min    max
# 0  675.865823   60  43016

# %% [markdown]
# ## Task 2

# %%
#Selecting trips started on Feb-02-2015 only 

query = '''
SELECT * FROM fb55.citibike
WHERE starttime BETWEEN '2/2/2015 00:00:00' AND '2/2/2015 23:59:59'

'''

table = get_data(query)
table.head(5)
# Out:
#    the_geom    start_station_name  the_geom_webmercator  field_1  \
# 0       NaN       5 Ave & E 29 St                   NaN     7433
# 1       NaN  Allen St & Hester St                   NaN     7779
# 2       NaN     E 5 St & Avenue C                   NaN       11
# 3       NaN       9 Ave & W 16 St                   NaN      627
# 4       NaN       9 Ave & W 16 St                   NaN      991
#
#    start_station_longitude  tripduration               starttime  \
# 0               -73.986831           376  2015-02-02 17:44:00+00
# 1               -73.991908          1217  2015-02-02 20:12:00+00
# 2               -73.979955          1312  2015-02-02 11:07:00+00
# 3               -74.004432           444  2015-02-02 00:40:00+00
# 4               -74.004432           438  2015-02-02 00:40:00+00
#
#                  stoptime  start_station_id  cartodb_id  \
# 0  2015-02-02 17:50:00+00               474        7367
# 1  2015-02-02 20:32:00+00               361        7712
# ...

# %%
#Selecting trips started on the weekends 
query = '''
SELECT * FROM fb55.citibike
WHERE EXTRACT(DOW FROM starttime::date) IN (0,6)

'''

table = get_data(query)
table.head()
# Out:
#    the_geom  start_station_name  the_geom_webmercator  field_1  \
# 0       NaN  E 20 St & Park Ave                   NaN      175
# 1       NaN    W 43 St & 10 Ave                   NaN     1159
# 2       NaN   E 6 St & Avenue B                   NaN     2827
# 3       NaN     E 12 St & 3 Ave                   NaN     4961
# 4       NaN     W 41 St & 8 Ave                   NaN     6156
#
#    start_station_longitude  tripduration               starttime  \
# 0               -73.987520          1090  2015-02-01 01:23:00+00
# 1               -73.994618           682  2015-02-01 10:55:00+00
# 2               -73.981854           751  2015-02-01 13:59:00+00
# 3               -73.988900           272  2015-02-01 17:28:00+00
# 4               -73.990026           240  2015-02-01 21:36:00+00
#
#                  stoptime  start_station_id  cartodb_id  \
# 0  2015-02-01 01:42:00+00               503         107
# 1  2015-02-01 11:07:00+00               515        1088
# ...

# %%
#What are average trip duration during weekends? 
query = '''
SELECT AVG(tripduration) FROM fb55.citibike
WHERE EXTRACT(DOW FROM starttime::date) IN (0,6)

'''
table = get_data(query)
table.head()
# Out:
#           avg  Unnamed: 1
# 0  662.942181         NaN

# %%
#weekday
query = '''
SELECT * FROM fb55.citibike
WHERE EXTRACT(DOW FROM starttime::date) IN (1,2,3,4,5)

'''

table = get_data(query)
table.head()
# Out:
#    the_geom    start_station_name  the_geom_webmercator  field_1  \
# 0       NaN       5 Ave & E 29 St                   NaN     7433
# 1       NaN  Allen St & Hester St                   NaN     7779
# 2       NaN       E 39 St & 3 Ave                   NaN     8327
# 3       NaN      10 Ave & W 28 St                   NaN     9435
# 4       NaN        E 2 St & 2 Ave                   NaN    10472
#
#    start_station_longitude  tripduration               starttime  \
# 0               -73.986831           376  2015-02-02 17:44:00+00
# 1               -73.991908          1217  2015-02-02 20:12:00+00
# 2               -73.976049           441  2015-02-03 08:02:00+00
# 3               -74.001768          1475  2015-02-03 12:31:00+00
# 4               -73.990697           420  2015-02-03 16:45:00+00
#
#                  stoptime  start_station_id  cartodb_id  \
# 0  2015-02-02 17:50:00+00               474        7367
# 1  2015-02-02 20:32:00+00               361        7712
# ...

# %%
#weekday tripduration average
query = '''
SELECT AVG(tripduration) FROM fb55.citibike
WHERE EXTRACT(DOW FROM starttime::date) IN (1,2,3,4,5)

'''
table = get_data(query)
table.head()
# Out:
#           avg  Unnamed: 1
# 0  681.052292         NaN

# %% [markdown]
# ## Task 3

# %%
#Showing the list of start station locations using group by
query = '''
SELECT start_station_name, start_station_longitude,start_station_latitude FROM fb55.citibike
GROUP BY start_station_name,start_station_longitude,start_station_latitude
'''
table = get_data(query)
table.head()
# Out:
#         start_station_name  start_station_longitude  start_station_latitude
# 0  Watts St & Greenwich St               -74.009660               40.724055
# 1          8 Ave & W 33 St               -73.993934               40.751551
# 2      Murray St & West St               -74.013012               40.714979
# 3          W 24 St & 7 Ave               -73.995299               40.744876
# 4          W 22 St & 8 Ave               -73.999154               40.744751

# %%
#start_station_latitude,
#start_station_longitude
#Showing the number of trips started per station 
query = '''
SELECT start_station_name, COUNT(start_station_name) FROM fb55.citibike
GROUP BY start_station_name
'''
table = get_data(query)
table.head()
# Out:
#         start_station_name  count
# 0     E 30 St & Park Ave S    227
# 1  Pearl St & Anchorage Pl     54
# 2          W 56 St & 6 Ave    164
# 3           West Thames St    107
# 4  Bank St & Washington St    125

# %%
#but only for stations within 500m of Time Square! 
#The coordinates of Time Square is (40.7577,-73.9857
#Each degree of latitude is approximately 69 miles (111 kilometers) apart
query = '''
SELECT start_station_name, start_station_longitude, start_station_latitude, COUNT(start_station_name) FROM fb55.citibike
WHERE SQRT(POWER(start_station_latitude-40.7577, 2) + POWER(start_station_longitude+73.9857, 2)) * 111000 < 500
GROUP BY start_station_name,start_station_longitude,start_station_latitude
'''
table = get_data(query)
table.head()
# Out:
#    start_station_name  start_station_longitude  start_station_latitude  count
# 0     W 45 St & 8 Ave               -73.988597               40.759291    141
# 1     W 45 St & 6 Ave               -73.982912               40.756800    141
# 2     W 43 St & 6 Ave               -73.983169               40.755273    112
# 3  Broadway & W 49 St               -73.984427               40.760647    213
# 4  Broadway & W 41 St               -73.986580               40.755136    251

# %% [markdown]
# ## Task 4

# %%
#Find the station that had the longest average trip duration during
#weekends and within 500m of TimeSquare! 
query = '''
SELECT start_station_name, AVG(tripduration) FROM fb55.citibike
WHERE EXTRACT(DOW FROM starttime::date) IN (0,6) 
AND
SQRT(POWER(start_station_latitude-40.7577, 2) + POWER(start_station_longitude+73.9857, 2)) * 111000 < 500
GROUP BY start_station_name
ORDER BY AVG(tripduration) DESC
LIMIT 1
'''

table = get_data(query)
table.head(1)
# Out:
#    start_station_name          avg
# 0  Broadway & W 49 St  1010.104167

# %%
#Extra: create lines for trips started from stations within 500m of Times
#Squares and lasted less than 2 hours. The number of trips per each
#pair of stations are output as attributes of these lines. 

query = '''
SELECT start_station_name, end_station_name, COUNT(tripduration) FROM fb55.citibike
WHERE SQRT(POWER(start_station_latitude-40.7577, 2) + POWER(start_station_longitude+73.9857, 2)) * 111000 < 500
AND
tripduration < 2 * 3600
GROUP BY start_station_name, end_station_name
'''
table = get_data(query)
table.head()
# Out:
#    start_station_name         end_station_name  count
# 0  Broadway & W 41 St          W 31 St & 7 Ave      2
# 1  Broadway & W 49 St    E 48 St & Madison Ave     13
# 2  Broadway & W 49 St          9 Ave & W 22 St      1
# 3  Broadway & W 49 St       Broadway & E 22 St      2
# 4     W 43 St & 6 Ave  E 37 St & Lexington Ave      4
